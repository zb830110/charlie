# %% [markdown]
# # Question 1 — Baseline circulating T-cell biomarkers of survival (nivo/chemo)
# This notebook performs median-split Kaplan–Meier + log-rank tests on baseline (C1D1) circulating T-cell populations in the **nivo/chemo** arm.
#
# **Input files** (provided):
# - `PICI0002_ph2_clinical.csv`
# - `NatureMed_CyTOF_metadata.csv`
# - `NatureMed_CyTOF_select_cell_populations.csv`

# %%
# %pip install pandas numpy lifelines matplotlib

# %%
import pandas as pd
import numpy as np

from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test

import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
clinical = pd.read_csv('PICI0002_ph2_clinical.csv')
cytof_long = pd.read_csv('NatureMed_CyTOF_select_cell_populations.csv')
meta = pd.read_csv('NatureMed_CyTOF_metadata.csv')

print('clinical', clinical.shape)
print('cytof_long', cytof_long.shape)
print('meta', meta.shape)

display(clinical.head())
display(cytof_long.head())
display(meta.head())
# Out:
# clinical (108, 29)
# cytof_long (1633, 3)
# meta (509, 4)
#    Deidentified.ID  Age Sex                       Race  \
# 0                2   67   F                      White
# 1                3   69   F                      White
# 2                4   54   M  Black or African American
# 3                6   64   M                      White
# 4                7   60   M                      White
#
#                 Ethnicity Arm               Arm Description Actual Arm  \
# 0  Not Hispanic or Latino  B2  B2: GEM/NP/APX005M 0.3 MG/KG         B2
# 1  Not Hispanic or Latino  B2  B2: GEM/NP/APX005M 0.3 MG/KG         B2
# 2  Not Hispanic or Latino  B2  B2: GEM/NP/APX005M 0.3 MG/KG         B2
# 3  Not Hispanic or Latino  B2  B2: GEM/NP/APX005M 0.3 MG/KG         B2
# 4  Not Hispanic or Latino  B2  B2: GEM/NP/APX005M 0.3 MG/KG         B2
#
#       Phase Participant Dosed  ... Prior Radiation Prior Chemo  \
# 0  PHASE 1B                 Y  ...               N           Y
# 1  PHASE 1B                 Y  ...               N           N
# 2  PHASE 1B                 Y  ...               N           N
# 3  PHASE 1B                 Y  ...               N           Y
# 4  PHASE 1B                 Y  ...               N           N
#
#   ECOG at Screening Tobacco History clinical.observation.os  \
# 0                 1          Former                     218
# 1                 1           Never                     966
# 2                 1           Never                     611
# 3                 1          Former                     675
# 4                 0          Former                     919
#
#   clinical.observation.os.event clinical.observation.pfs  \
# 0                          True                       55
# 1                         False                      351
# 2                          True                      280
# 3                          True                      168
# 4                         False                      512
#
#   clinical.observation.pfs.event  \
# 0                           True
# 1                          False
# 2                           True
# 3                           True
# 4                           True
#
#                      clinical.observation.pfs.reason Best Overall Response
# 0      :clinical-observation.event-reason/progressed   PROGRESSIVE DISEASE
# 1  :clinical-observation.event-reason/censored-st...      PARTIAL RESPONSE
# 2      :clinical-observation.event-reason/progressed        STABLE DISEASE
# 3      :clinical-observation.event-reason/progressed        STABLE DISEASE
# 4      :clinical-observation.event-reason/progressed        STABLE DISEASE
#
# [5 rows x 29 columns]
#                          sample.id     value  \
# 0  PICI0002_A01_K01427KE01_SPB_A03  0.000087
# 1  PICI0002_A16_K06268KE01_SPB_A01  0.000067
# 2                      BK00972EB02  0.000062
# 3                      BK00971EB01  0.000024
# 4                      BK00975EB01  0.000029
#
#                           paper.name
# 0  CD1C+ CD141+ DC (% of leukocytes)
# 1  CD1C+ CD141+ DC (% of leukocytes)
# 2  CD1C+ CD141+ DC (% of leukocytes)
# 3  CD1C+ CD141+ DC (% of leukocytes)
# 4  CD1C+ CD141+ DC (% of leukocytes)
#    Deidentified.ID                        sample.id                  ms  \
# 0                2  PICI0002_A05_K01609KE01_SPB_A01  Blood: CyTOF %leuk
# 1                2  PICI0002_A01_K00891KE01_SPB_A01   Blood: CyTOF %par
# 2                2  PICI0002_A01_K00891KE01_SPB_A01  Blood: CyTOF %leuk
# 3                2  PICI0002_A06_K01343KE01_SPB_A01  Blood: CyTOF %leuk
# 4                3  PICI0002_A06_K00943CP01_SPB_A02  Blood: CyTOF %leuk
#
#   timepoint.id
# 0        C1D15
# 1         C1D1
# 2         C1D1
# 3         C2D1
# 4         C2D1

# %% [markdown]
# ## Identify columns to use
# Expecting:
# - patient identifier: `Deidentified.ID`
# - treatment arm: `Arm` (A1 = nivo/chemo)
# - survival time/event: `clinical.observation.os`, `clinical.observation.os.event`
# - CyTOF sample identifier: `sample.id`
# - CyTOF feature name: `paper.name`
# - CyTOF frequency value: `value`
# - timepoint: `timepoint.id` (baseline is `C1D1`)

# %%
print('Clinical columns:', list(clinical.columns))
print('CyTOF columns:', list(cytof_long.columns))
print('Meta columns:', list(meta.columns))

print('Clinical arms:', clinical['Arm Description'].dropna().unique())
print('Meta timepoints:', sorted(meta['timepoint.id'].unique()))
print('CyTOF features (paper.name):')
print(sorted(cytof_long['paper.name'].unique()))
# Out:
# Clinical columns: ['Deidentified.ID', 'Age', 'Sex', 'Race', 'Ethnicity', 'Arm', 'Arm Description', 'Actual Arm', 'Phase', 'Participant Dosed', 'Received APX005M', 'Received Nivolumab', 'DLT Evaluable', 'Efficacy Population Flag', 'Cancer Type', 'Cancer Location', 'Stage at Initial Diagnosis', 'Stage at Enrollment', 'Prior Cancer Surgery', 'Prior Radiation', 'Prior Chemo', 'ECOG at Screening', 'Tobacco History', 'clinical.observation.os', 'clinical.observation.os.event', 'clinical.observation.pfs', 'clinical.observation.pfs.event', 'clinical.observation.pfs.reason', 'Best Overall Response']
# CyTOF columns: ['sample.id', 'value', 'paper.name']
# Meta columns: ['Deidentified.ID', 'sample.id', 'ms', 'timepoint.id']
# Clinical arms: ['B2: GEM/NP/APX005M 0.3 MG/KG' 'C2: GEM/NP/NIVOLUMAB/APX005M 0.3 MG/KG'
#  'PHASE II A1: GEM/NP/NIVOLUMAB'
#  'PHASE II C2: GEM/NP/NIVOLUMAB/APX005M 0.3 MG/KG'
#  'PHASE II B2: GEM/NP/APX005M 0.3 MG/KG']
# Meta timepoints: ['C1D1', 'C1D15', 'C2D1', 'C4D1']
# CyTOF features (paper.name):
# ['CCR7+ CD11b+ CD27- B cells', 'CD14+ HLA-DRlo m-MDSC (% of leukocytes)', 'CD141+ Cross Presenting DC', 'CD1C+ CD141+ DC (% of leukocytes)', 'CD1c-CD141+ Cross Presenting DC', 'CD40+ pDC (% of pDC)', 'Conventional DC', 'HLA-DR+ CCR7+ B cells (% of leukocytes)', 'HLA-DR+ Non-Naive CD4 T Cells', 'HLA-DR+ Non-Naive CD8 T Cells', 'HLA-DR+ Plasmablasts (% of Plasmablasts)', 'HLA-DR+ T cells (% of leukocytes)', 'Ki-67+ T cells (% of CD3+ cells)', 'NKT cells (% of leukocytes)', 'Tbet+ T cells (% of CD3+ cells)', 'Tbet+ TCRgd+ T cells (% of TCRgd T cells)']

# %% [markdown]
# ## Reshape CyTOF to wide format (one row per sample)
# The CyTOF file is in long format (sample × feature). Pivot to wide so each feature becomes a column.

# %%
cytof_wide = cytof_long.pivot_table(index='sample.id', columns='paper.name', values='value', aggfunc='first').reset_index()
print('cytof_wide', cytof_wide.shape)
display(cytof_wide)
# Out:
# cytof_wide (263, 17)
# paper.name                        sample.id  CCR7+ CD11b+ CD27- B cells  \
# 0                               BK00033EB01                    0.000810
# 1                               BK00052EB02                    0.000197
# 2                               BK00072EB02                    0.000477
# 3                               BK00083EB01                    0.000652
# 4                               BK00092EB01                    0.000298
# ..                                      ...                         ...
# 258         PICI0002_A06_K01818KE01_SPB_A03                    0.028235
# 259         PICI0002_A06_K06384KE01_SPB_A01                    0.002927
# 260         PICI0002_A11_K01942KE01_SPB_A02                    0.000700
# 261         PICI0002_A16_K06191KE01_SPB_A02                         NaN
# 262         PICI0002_A16_K06268KE01_SPB_A01                    0.010286
#
# paper.name  CD14+ HLA-DRlo m-MDSC (% of leukocytes)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                          0.089852
# ..                                              ...
# 258                                             NaN
# 259                                             NaN
# 260                                             NaN
# 261                                             NaN
# 262                                        0.020036
#
# paper.name  CD141+ Cross Presenting DC  CD1C+ CD141+ DC (% of leukocytes)  \
# 0                                  NaN                                NaN
# 1                             0.000229                                NaN
# 2                             0.000180                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                           0.000014
# ..                                 ...                                ...
# 258                                NaN                                NaN
# 259                                NaN                                NaN
# 260                                NaN                                NaN
# 261                                NaN                                NaN
# 262                                NaN                           0.000067
#
# paper.name  CD1c-CD141+ Cross Presenting DC  CD40+ pDC (% of pDC)  \
# 0                                  0.000137                   NaN
# 1                                       NaN                   NaN
# 2                                  0.000090                   NaN
# 3                                  0.000065                   NaN
# 4                                       NaN              0.000003
# ..                                      ...                   ...
# 258                                     NaN                   NaN
# 259                                     NaN                   NaN
# 260                                     NaN                   NaN
# 261                                     NaN              0.000051
# 262                                     NaN              0.000019
#
# paper.name  Conventional DC  HLA-DR+ CCR7+ B cells (% of leukocytes)  \
# 0                       NaN                                      NaN
# 1                       NaN                                      NaN
# 2                       NaN                                      NaN
# 3                       NaN                                      NaN
# 4                       NaN                                 0.059357
# ..                      ...                                      ...
# 258                0.011264                                      NaN
# 259                0.002560                                      NaN
# 260                     NaN                                      NaN
# 261                     NaN                                      NaN
# 262                     NaN                                 0.104581
#
# paper.name  HLA-DR+ Non-Naive CD4 T Cells  HLA-DR+ Non-Naive CD8 T Cells  \
# 0                                0.009640                       0.010560
# 1                                0.104875                       0.142081
# 2                                0.099729                       0.153511
# 3                                0.078415                       0.142845
# 4                                0.054455                       0.052884
# ..                                    ...                            ...
# 258                              0.116619                       0.136009
# 259                              0.130154                       0.259506
# 260                              0.152146                       0.198609
# 261                                   NaN                            NaN
# 262                              0.225295                       0.248609
#
# paper.name  HLA-DR+ Plasmablasts (% of Plasmablasts)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           0.000225
# ..                                               ...
# 258                                              NaN
# 259                                              NaN
# 260                                              NaN
# 261                                         0.000147
# 262                                         0.001034
#
# paper.name  HLA-DR+ T cells (% of leukocytes)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                    0.028703
# ..                                        ...
# 258                                       NaN
# 259                                       NaN
# 260                                       NaN
# 261                                  0.066540
# 262                                  0.098679
#
# paper.name  Ki-67+ T cells (% of CD3+ cells)  NKT cells (% of leukocytes)  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                   0.874194                     0.044607
# ..                                       ...                          ...
# 258                                      NaN                          NaN
# 259                                      NaN                          NaN
# 260                                      NaN                          NaN
# 261                                 0.942225                     0.009655
# 262                                 0.928504                     0.008597
#
# paper.name  Tbet+ T cells (% of CD3+ cells)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                  0.203980
# ..                                      ...
# 258                                     NaN
# 259                                     NaN
# 260                                     NaN
# 261                                0.299116
# 262                                0.177628
#
# paper.name  Tbet+ TCRgd+ T cells (% of TCRgd T cells)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                            0.847944
# ..                                                ...
# 258                                               NaN
# 259                                               NaN
# 260                                               NaN
# 261                                          0.564482
# 262                                          0.697401
#
# [263 rows x 17 columns]

# %% [markdown]
# ## Merge CyTOF with metadata (adds patient + timepoint)

# %%
cytof_full = cytof_wide.merge(meta, on='sample.id', how='left')
print('cytof_full', cytof_full.shape)

# Check merge completeness
print('Missing Deidentified.ID:', cytof_full['Deidentified.ID'].isna().sum())
print('Missing timepoint.id:', cytof_full['timepoint.id'].isna().sum())

display(cytof_full)
# Out:
# cytof_full (509, 20)
# Missing Deidentified.ID: 0
# Missing timepoint.id: 0
#                            sample.id  CCR7+ CD11b+ CD27- B cells  \
# 0                        BK00033EB01                    0.000810
# 1                        BK00033EB01                    0.000810
# 2                        BK00052EB02                    0.000197
# 3                        BK00052EB02                    0.000197
# 4                        BK00072EB02                    0.000477
# ..                               ...                         ...
# 504  PICI0002_A11_K01942KE01_SPB_A02                    0.000700
# 505  PICI0002_A16_K06191KE01_SPB_A02                         NaN
# 506  PICI0002_A16_K06191KE01_SPB_A02                         NaN
# 507  PICI0002_A16_K06268KE01_SPB_A01                    0.010286
# 508  PICI0002_A16_K06268KE01_SPB_A01                    0.010286
#
#      CD14+ HLA-DRlo m-MDSC (% of leukocytes)  CD141+ Cross Presenting DC  \
# 0                                        NaN                         NaN
# 1                                        NaN                         NaN
# 2                                        NaN                    0.000229
# 3                                        NaN                    0.000229
# 4                                        NaN                    0.000180
# ..                                       ...                         ...
# 504                                      NaN                         NaN
# 505                                      NaN                         NaN
# 506                                      NaN                         NaN
# 507                                 0.020036                         NaN
# 508                                 0.020036                         NaN
#
#      CD1C+ CD141+ DC (% of leukocytes)  CD1c-CD141+ Cross Presenting DC  \
# 0                                  NaN                         0.000137
# 1                                  NaN                         0.000137
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                         0.000090
# ..                                 ...                              ...
# 504                                NaN                              NaN
# 505                                NaN                              NaN
# 506                                NaN                              NaN
# 507                           0.000067                              NaN
# 508                           0.000067                              NaN
#
#      CD40+ pDC (% of pDC)  Conventional DC  \
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3                     NaN              NaN
# 4                     NaN              NaN
# ..                    ...              ...
# 504                   NaN              NaN
# 505              0.000051              NaN
# 506              0.000051              NaN
# 507              0.000019              NaN
# 508              0.000019              NaN
#
#      HLA-DR+ CCR7+ B cells (% of leukocytes)  HLA-DR+ Non-Naive CD4 T Cells  \
# 0                                        NaN                       0.009640
# 1                                        NaN                       0.009640
# 2                                        NaN                       0.104875
# 3                                        NaN                       0.104875
# 4                                        NaN                       0.099729
# ..                                       ...                            ...
# 504                                      NaN                       0.152146
# 505                                      NaN                            NaN
# 506                                      NaN                            NaN
# 507                                 0.104581                       0.225295
# 508                                 0.104581                       0.225295
#
#      HLA-DR+ Non-Naive CD8 T Cells  HLA-DR+ Plasmablasts (% of Plasmablasts)  \
# 0                         0.010560                                       NaN
# 1                         0.010560                                       NaN
# 2                         0.142081                                       NaN
# 3                         0.142081                                       NaN
# 4                         0.153511                                       NaN
# ..                             ...                                       ...
# 504                       0.198609                                       NaN
# 505                            NaN                                  0.000147
# 506                            NaN                                  0.000147
# 507                       0.248609                                  0.001034
# 508                       0.248609                                  0.001034
#
#      HLA-DR+ T cells (% of leukocytes)  Ki-67+ T cells (% of CD3+ cells)  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ..                                 ...                               ...
# 504                                NaN                               NaN
# 505                           0.066540                          0.942225
# 506                           0.066540                          0.942225
# 507                           0.098679                          0.928504
# 508                           0.098679                          0.928504
#
#      NKT cells (% of leukocytes)  Tbet+ T cells (% of CD3+ cells)  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ..                           ...                              ...
# 504                          NaN                              NaN
# 505                     0.009655                         0.299116
# 506                     0.009655                         0.299116
# 507                     0.008597                         0.177628
# 508                     0.008597                         0.177628
#
#      Tbet+ TCRgd+ T cells (% of TCRgd T cells)  Deidentified.ID  \
# 0                                          NaN               92
# 1                                          NaN               92
# 2                                          NaN               96
# 3                                          NaN               96
# 4                                          NaN               94
# ..                                         ...              ...
# 504                                        NaN               47
# 505                                   0.564482               65
# 506                                   0.564482               65
# 507                                   0.697401                9
# 508                                   0.697401                9
#
#                      ms timepoint.id
# 0     Blood: CyTOF %par        C1D15
# 1    Blood: CyTOF %leuk        C1D15
# 2    Blood: CyTOF %leuk        C1D15
# 3     Blood: CyTOF %par        C1D15
# 4     Blood: CyTOF %par        C1D15
# ..                  ...          ...
# 504   Blood: CyTOF %par         C4D1
# 505  Blood: CyTOF %leuk         C1D1
# 506   Blood: CyTOF %par         C1D1
# 507   Blood: CyTOF %par         C1D1
# 508  Blood: CyTOF %leuk         C1D1
#
# [509 rows x 20 columns]

# %% [markdown]
# ## Filter to baseline (C1D1) and nivo/chemo arm (A1)
# Mapping used in this trial dataset:
# - **A1**: Gemcitabine/nab-paclitaxel + **nivolumab** (nivo/chemo)
# - **B2**: Gem/nab-paclitaxel + **APX005M** (CD40 agonist; sotiga/chemo)
# - **C2**: Gem/nab-paclitaxel + **nivolumab + APX005M** (triplet)

# %%
BASELINE_TP = 'C1D1'
NIVO_ARM = 'A1'

cytof_base = cytof_full[cytof_full['timepoint.id'] == BASELINE_TP].copy()
clinical_nivo = clinical[clinical['Arm'] == NIVO_ARM].copy()

print('cytof_base', cytof_base.shape)
print('clinical_nivo', clinical_nivo.shape)
display(cytof_base)
display(clinical_nivo)
# Out:
# cytof_base (164, 20)
# clinical_nivo (34, 29)
#                            sample.id  CCR7+ CD11b+ CD27- B cells  \
# 8                        BK00092EB01                    0.000298
# 9                        BK00092EB01                    0.000298
# 16                       BK00125EB01                    0.002677
# 17                       BK00125EB01                    0.002677
# 18                       BK00147EB01                    0.001098
# ..                               ...                         ...
# 469  PICI0002_A01_K06378KE01_SPB_A01                    0.001382
# 505  PICI0002_A16_K06191KE01_SPB_A02                         NaN
# 506  PICI0002_A16_K06191KE01_SPB_A02                         NaN
# 507  PICI0002_A16_K06268KE01_SPB_A01                    0.010286
# 508  PICI0002_A16_K06268KE01_SPB_A01                    0.010286
#
#      CD14+ HLA-DRlo m-MDSC (% of leukocytes)  CD141+ Cross Presenting DC  \
# 8                                   0.089852                         NaN
# 9                                   0.089852                         NaN
# 16                                  0.066600                         NaN
# 17                                  0.066600                         NaN
# 18                                  0.013744                         NaN
# ..                                       ...                         ...
# 469                                 0.134093                         NaN
# 505                                      NaN                         NaN
# 506                                      NaN                         NaN
# 507                                 0.020036                         NaN
# 508                                 0.020036                         NaN
#
#      CD1C+ CD141+ DC (% of leukocytes)  CD1c-CD141+ Cross Presenting DC  \
# 8                             0.000014                              NaN
# 9                             0.000014                              NaN
# 16                            0.000031                              NaN
# 17                            0.000031                              NaN
# 18                            0.000045                              NaN
# ..                                 ...                              ...
# 469                           0.000062                              NaN
# 505                                NaN                              NaN
# 506                                NaN                              NaN
# 507                           0.000067                              NaN
# 508                           0.000067                              NaN
#
#      CD40+ pDC (% of pDC)  Conventional DC  \
# 8                0.000003              NaN
# 9                0.000003              NaN
# 16               0.000003              NaN
# 17               0.000003              NaN
# 18               0.000010              NaN
# ..                    ...              ...
# 469              0.000000              NaN
# 505              0.000051              NaN
# 506              0.000051              NaN
# 507              0.000019              NaN
# 508              0.000019              NaN
#
#      HLA-DR+ CCR7+ B cells (% of leukocytes)  HLA-DR+ Non-Naive CD4 T Cells  \
# 8                                   0.059357                       0.054455
# 9                                   0.059357                       0.054455
# 16                                  0.067780                       0.053034
# 17                                  0.067780                       0.053034
# 18                                  0.066508                       0.127584
# ..                                       ...                            ...
# 469                                 0.028603                       0.035831
# 505                                      NaN                            NaN
# 506                                      NaN                            NaN
# 507                                 0.104581                       0.225295
# 508                                 0.104581                       0.225295
#
#      HLA-DR+ Non-Naive CD8 T Cells  HLA-DR+ Plasmablasts (% of Plasmablasts)  \
# 8                         0.052884                                  0.000225
# 9                         0.052884                                  0.000225
# 16                        0.069605                                  0.000242
# 17                        0.069605                                  0.000242
# 18                        0.138874                                  0.000301
# ..                             ...                                       ...
# 469                       0.063643                                  0.000257
# 505                            NaN                                  0.000147
# 506                            NaN                                  0.000147
# 507                       0.248609                                  0.001034
# 508                       0.248609                                  0.001034
#
#      HLA-DR+ T cells (% of leukocytes)  Ki-67+ T cells (% of CD3+ cells)  \
# 8                             0.028703                          0.874194
# 9                             0.028703                          0.874194
# 16                            0.029428                          0.901677
# 17                            0.029428                          0.901677
# 18                            0.087462                          0.894343
# ..                                 ...                               ...
# 469                           0.019728                          0.993612
# 505                           0.066540                          0.942225
# 506                           0.066540                          0.942225
# 507                           0.098679                          0.928504
# 508                           0.098679                          0.928504
#
#      NKT cells (% of leukocytes)  Tbet+ T cells (% of CD3+ cells)  \
# 8                       0.044607                         0.203980
# 9                       0.044607                         0.203980
# 16                      0.007949                         0.113270
# 17                      0.007949                         0.113270
# 18                      0.026749                         0.393437
# ..                           ...                              ...
# 469                     0.000924                         0.037423
# 505                     0.009655                         0.299116
# 506                     0.009655                         0.299116
# 507                     0.008597                         0.177628
# 508                     0.008597                         0.177628
#
#      Tbet+ TCRgd+ T cells (% of TCRgd T cells)  Deidentified.ID  \
# 8                                     0.847944               67
# 9                                     0.847944               67
# 16                                    0.469105              124
# 17                                    0.469105              124
# 18                                    0.941372              122
# ..                                         ...              ...
# 469                                   0.749263               16
# 505                                   0.564482               65
# 506                                   0.564482               65
# 507                                   0.697401                9
# 508                                   0.697401                9
#
#                      ms timepoint.id
# 8     Blood: CyTOF %par         C1D1
# 9    Blood: CyTOF %leuk         C1D1
# 16   Blood: CyTOF %leuk         C1D1
# 17    Blood: CyTOF %par         C1D1
# 18    Blood: CyTOF %par         C1D1
# ..                  ...          ...
# 469  Blood: CyTOF %leuk         C1D1
# 505  Blood: CyTOF %leuk         C1D1
# 506   Blood: CyTOF %par         C1D1
# 507   Blood: CyTOF %par         C1D1
# 508  Blood: CyTOF %leuk         C1D1
#
# [164 rows x 20 columns]
#      Deidentified.ID  Age Sex   Race               Ethnicity Arm  \
# 6                  9   53   F  White  Not Hispanic or Latino  A1
# 7                 10   59   F  Asian  Not Hispanic or Latino  A1
# 8                 11   65   F  Asian  Not Hispanic or Latino  A1
# 9                 12   65   M  White  Not Hispanic or Latino  A1
# 13                16   60   M  White  Not Hispanic or Latino  A1
# 15                18   69   M  White  Not Hispanic or Latino  A1
# 16                19   75   M  White  Not Hispanic or Latino  A1
# 18                21   64   F  White  Not Hispanic or Latino  A1
# 24                29   75   M  White  Not Hispanic or Latino  A1
# 26                31   54   M  White  Not Hispanic or Latino  A1
# 28                33   67   M  White  Not Hispanic or Latino  A1
# 30                35   69   F  White  Not Hispanic or Latino  A1
# 37                42   71   F  White  Not Hispanic or Latino  A1
# 38                43   61   M  White  Not Hispanic or Latino  A1
# 40                45   50   M  White  Not Hispanic or Latino  A1
# 46                51   61   F  Asian  Not Hispanic or Latino  A1
# 49                54   48   F  White  Not Hispanic or Latino  A1
# 54                59   54   M  White  Not Hispanic or Latino  A1
# 55                61   70   F  White  Not Hispanic or Latino  A1
# 60                68   59   M  White  Not Hispanic or Latino  A1
# 65                73   66   M  White  Not Hispanic or Latino  A1
# 68                76   62   M  White  Not Hispanic or Latino  A1
# 72                90   68   M  White  Not Hispanic or Latino  A1
# 73                91   63   F  White  Not Hispanic or Latino  A1
# 74                92   54   F  White  Not Hispanic or Latino  A1
# 77                97   67   M  White  Not Hispanic or Latino  A1
# 78                98   52   F  Other  Not Hispanic or Latino  A1
# 81               101   67   M  White  Not Hispanic or Latino  A1
# 89               111   64   M  White  Not Hispanic or Latino  A1
# 91               113   51   M  White  Not Hispanic or Latino  A1
# 95               117   67   M  White  Not Hispanic or Latino  A1
# 97               119   51   F  White  Not Hispanic or Latino  A1
# 99               121   47   M  White  Not Hispanic or Latino  A1
# 106              128   56   F  Other      Hispanic or Latino  A1
#
#                    Arm Description Actual Arm     Phase Participant Dosed  \
# 6    PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 7    PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 8    PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 9    PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 13   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 15   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 16   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 18   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 24   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 26   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 28   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 30   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 37   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 38   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 40   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 46   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 49   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 54   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 55   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 60   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 65   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 68   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 72   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 73   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 74   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 77   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 78   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 81   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 89   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 91   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 95   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 97   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 99   PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
# 106  PHASE II A1: GEM/NP/NIVOLUMAB         A1  PHASE II                 Y
#
#      ... Prior Radiation Prior Chemo ECOG at Screening Tobacco History  \
# 6    ...               N           Y                 0          Former
# 7    ...               N           N                 1           Never
# 8    ...               N           N                 0          Former
# 9    ...               N           Y                 1           Never
# 13   ...               N           N                 1         Current
# 15   ...               N           N                 1           Never
# 16   ...               N           Y                 1          Former
# 18   ...               N           Y                 0          Former
# 24   ...               N           Y                 0           Never
# 26   ...               N           N                 0           Never
# 28   ...               N           N                 0           Never
# 30   ...               N           N                 0           Never
# 37   ...               N           N                 0          Former
# 38   ...               N           N                 0           Never
# 40   ...               N           N                 0           Never
# 46   ...               N           N                 0           Never
# 49   ...               N           N                 0           Never
# 54   ...               N           Y                 0           Never
# 55   ...               N           N                 1          Former
# 60   ...               N           N                 1           Never
# 65   ...               N           N                 1           Never
# 68   ...               N           Y                 1          Former
# 72   ...               N           N                 1         Current
# 73   ...               N           N                 1         Current
# 74   ...               N           N                 1          Former
# 77   ...               N           N                 1           Never
# 78   ...               N           N                 1           Never
# 81   ...               N           N                 1           Never
# 89   ...               N           N                 1          Former
# 91   ...               N           N                 1          Former
# 95   ...               N           N                 1          Former
# 97   ...               N           N                 1          Former
# 99   ...               N           Y                 0           Never
# 106  ...               N           Y                 0           Never
#
#     clinical.observation.os clinical.observation.os.event  \
# 6                       620                          True
# 7                       253                          True
# 8                       673                         False
# 9                       530                          True
# 13                      297                          True
# 15                      249                          True
# 16                      194                          True
# 18                      467                          True
# 24                      779                         False
# 26                      726                          True
# 28                      747                         False
# 30                      163                         False
# 37                       43                         False
# 38                       85                          True
# 40                      560                          True
# 46                      194                          True
# 49                      309                          True
# 54                      478                         False
# 55                       96                          True
# 60                      539                          True
# 65                      301                          True
# 68                      660                         False
# 72                      107                          True
# 73                      186                          True
# 74                      445                          True
# 77                      737                          True
# 78                      303                          True
# 81                      723                         False
# 89                       43                         False
# 91                      544                          True
# 95                      245                          True
# 97                      568                         False
# 99                      508                          True
# 106                     213                         False
#
#     clinical.observation.pfs clinical.observation.pfs.event  \
# 6                        157                           True
# 7                        161                           True
# 8                        575                          False
# 9                         98                           True
# 13                       296                           True
# 15                       147                           True
# 16                       193                           True
# 18                       272                           True
# 24                        99                           True
# 26                       725                           True
# 28                        62                           True
# 30                       175                           True
# 37                        55                           True
# 38                        84                           True
# 40                       559                           True
# 46                       193                           True
# 49                        49                           True
# 54                       267                           True
# 55                        95                           True
# 60                       538                           True
# 65                       196                           True
# 68                       288                          False
# 72                       106                           True
# 73                       185                           True
# 74                       225                           True
# 77                       594                           True
# 78                       177                           True
# 81                       176                          False
# 89                        48                           True
# 91                       543                           True
# 95                       244                           True
# 97                       405                          False
# 99                       507                           True
# 106                      219                           True
#
#                        clinical.observation.pfs.reason Best Overall Response
# 6        :clinical-observation.event-reason/progressed      PARTIAL RESPONSE
# 7        :clinical-observation.event-reason/progressed      PARTIAL RESPONSE
# 8    :clinical-observation.event-reason/censored-st...      PARTIAL RESPONSE
# 9        :clinical-observation.event-reason/progressed        STABLE DISEASE
# 13             :clinical-observation.event-reason/dead                   NaN
# 15       :clinical-observation.event-reason/progressed        STABLE DISEASE
# 16             :clinical-observation.event-reason/dead         NOT EVALUABLE
# 18       :clinical-observation.event-reason/progressed      PARTIAL RESPONSE
# 24       :clinical-observation.event-reason/progressed   PROGRESSIVE DISEASE
# 26             :clinical-observation.event-reason/dead      PARTIAL RESPONSE
# 28       :clinical-observation.event-reason/progressed   PROGRESSIVE DISEASE
# 30       :clinical-observation.event-reason/progressed      PARTIAL RESPONSE
# 37       :clinical-observation.event-reason/progressed   PROGRESSIVE DISEASE
# 38             :clinical-observation.event-reason/dead                   NaN
# 40             :clinical-observation.event-reason/dead      PARTIAL RESPONSE
# 46             :clinical-observation.event-reason/dead      PARTIAL RESPONSE
# 49       :clinical-observation.event-reason/progressed   PROGRESSIVE DISEASE
# 54       :clinical-observation.event-reason/progressed        STABLE DISEASE
# 55             :clinical-observation.event-reason/dead        STABLE DISEASE
# 60             :clinical-observation.event-reason/dead        STABLE DISEASE
# 65       :clinical-observation.event-reason/progressed        STABLE DISEASE
# 68   :clinical-observation.event-reason/censored-st...      PARTIAL RESPONSE
# 72             :clinical-observation.event-reason/dead                   NaN
# 73             :clinical-observation.event-reason/dead        STABLE DISEASE
# 74       :clinical-observation.event-reason/progressed      PARTIAL RESPONSE
# 77       :clinical-observation.event-reason/progressed      PARTIAL RESPONSE
# 78       :clinical-observation.event-reason/progressed      PARTIAL RESPONSE
# 81   :clinical-observation.event-reason/censored-st...        STABLE DISEASE
# 89       :clinical-observation.event-reason/progressed   PROGRESSIVE DISEASE
# 91             :clinical-observation.event-reason/dead      PARTIAL RESPONSE
# 95             :clinical-observation.event-reason/dead      PARTIAL RESPONSE
# 97   :clinical-observation.event-reason/censored-st...     COMPLETE RESPONSE
# 99             :clinical-observation.event-reason/dead      PARTIAL RESPONSE
# 106      :clinical-observation.event-reason/progressed      PARTIAL RESPONSE
#
# [34 rows x 29 columns]

# %% [markdown]
# ## Merge baseline CyTOF with survival
# Merge on `Deidentified.ID`. Survival columns are:
# - `clinical.observation.os` (time)
# - `clinical.observation.os.event` (1=death, 0=censored)

# %%
data = cytof_base.merge(
    clinical_nivo[['Deidentified.ID','clinical.observation.os','clinical.observation.os.event']],
    on='Deidentified.ID',
    how='inner'
)

# Rename for clarity
data = data.rename(columns={
    'clinical.observation.os': 'OS_time',
    'clinical.observation.os.event': 'OS_event'
})

print('analysis data', data.shape)
display(data[['Deidentified.ID','timepoint.id','OS_time','OS_event']])
print('OS_event counts:', data['OS_event'].value_counts(dropna=False).to_dict())
# Out:
# analysis data (50, 22)
#     Deidentified.ID timepoint.id  OS_time  OS_event
# 0               128         C1D1      213     False
# 1               128         C1D1      213     False
# 2               121         C1D1      508      True
# 3               121         C1D1      508      True
# 4                31         C1D1      726      True
# 5                31         C1D1      726      True
# 6                29         C1D1      779     False
# 7                29         C1D1      779     False
# 8                92         C1D1      445      True
# 9                92         C1D1      445      True
# 10               91         C1D1      186      True
# 11               91         C1D1      186      True
# 12               51         C1D1      194      True
# 13               51         C1D1      194      True
# 14               54         C1D1      309      True
# 15               54         C1D1      309      True
# 16               12         C1D1      530      True
# 17               12         C1D1      530      True
# 18               11         C1D1      673     False
# 19               11         C1D1      673     False
# 20               33         C1D1      747     False
# 21               33         C1D1      747     False
# 22               42         C1D1       43     False
# 23               42         C1D1       43     False
# 24               35         C1D1      163     False
# 25               35         C1D1      163     False
# 26               73         C1D1      301      True
# 27               73         C1D1      301      True
# 28              111         C1D1       43     False
# 29              111         C1D1       43     False
# 30               19         C1D1      194      True
# 31               19         C1D1      194      True
# 32               18         C1D1      249      True
# 33               18         C1D1      249      True
# 34              101         C1D1      723     False
# 35              101         C1D1      723     False
# 36               21         C1D1      467      True
# 37               21         C1D1      467      True
# 38               59         C1D1      478     False
# 39               59         C1D1      478     False
# 40              117         C1D1      245      True
# 41              117         C1D1      245      True
# 42               76         C1D1      660     False
# 43               76         C1D1      660     False
# 44              119         C1D1      568     False
# 45              119         C1D1      568     False
# 46               16         C1D1      297      True
# 47               16         C1D1      297      True
# 48                9         C1D1      620      True
# 49                9         C1D1      620      True
# OS_event counts: {True: 28, False: 22}

# %% [markdown]
# ## Select circulating T-cell features to test
# This CyTOF subset file contains a limited set of preselected populations. For Question 1, I will test the T-cell-related features present here.
#
# Edit `tcell_features` to add/remove populations from this file.

# %%
all_features = [c for c in data.columns if c not in ['sample.id','Deidentified.ID','ms','timepoint.id','OS_time','OS_event']]
print(all_features)

# Heuristic: keep features with 'T cell' in the name
candidate = [c for c in all_features if 'T cell' in c or 'T cells' in c]
print('Candidate T-cell features:')
for c in candidate:
    print(' -', c)

# Default set: expand/adjust as desired
tcell_features = list(candidate)
print('\nTesting features:', tcell_features)
# Out:
# ['CCR7+ CD11b+ CD27- B cells', 'CD14+ HLA-DRlo m-MDSC (% of leukocytes)', 'CD141+ Cross Presenting DC', 'CD1C+ CD141+ DC (% of leukocytes)', 'CD1c-CD141+ Cross Presenting DC', 'CD40+ pDC (% of pDC)', 'Conventional DC', 'HLA-DR+ CCR7+ B cells (% of leukocytes)', 'HLA-DR+ Non-Naive CD4 T Cells', 'HLA-DR+ Non-Naive CD8 T Cells', 'HLA-DR+ Plasmablasts (% of Plasmablasts)', 'HLA-DR+ T cells (% of leukocytes)', 'Ki-67+ T cells (% of CD3+ cells)', 'NKT cells (% of leukocytes)', 'Tbet+ T cells (% of CD3+ cells)', 'Tbet+ TCRgd+ T cells (% of TCRgd T cells)']
# Candidate T-cell features:
#  - HLA-DR+ T cells (% of leukocytes)
#  - Ki-67+ T cells (% of CD3+ cells)
#  - NKT cells (% of leukocytes)
#  - Tbet+ T cells (% of CD3+ cells)
#  - Tbet+ TCRgd+ T cells (% of TCRgd T cells)
#
# Testing features: ['HLA-DR+ T cells (% of leukocytes)', 'Ki-67+ T cells (% of CD3+ cells)', 'NKT cells (% of leukocytes)', 'Tbet+ T cells (% of CD3+ cells)', 'Tbet+ TCRgd+ T cells (% of TCRgd T cells)']

# %% [markdown]
# ## Kaplan–Meier + log-rank (median split)
# For each feature, split patients into High (>= median) vs Low (< median) and run a log-rank test.
#
# If I split patients into “high” vs “low” based on this baseline immune feature, do they survive differently over time?

# %%
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test

kmf = KaplanMeierFitter()
results = []

for feature in tcell_features:
    # Drop missing feature values for this feature
    df = data.loc[~data[feature].isna(), ['OS_time','OS_event', feature]].copy()
    if df.shape[0] < 10:
        continue

    med = df[feature].median()
    high_mask = df[feature] >= med

    high = df.loc[high_mask]
    low = df.loc[~high_mask]

    lr = logrank_test(
        high['OS_time'], low['OS_time'],
        event_observed_A=high['OS_event'],
        event_observed_B=low['OS_event']
    )

    results.append({
        'feature': feature,
        'median': float(med),
        'logrank_p': float(lr.p_value),
        'n_high': int(high.shape[0]),
        'n_low': int(low.shape[0])
    })

results_df = pd.DataFrame(results).sort_values('logrank_p').reset_index(drop=True)
results_df.to_csv('results_question1_logrank.csv', index=False)

print('Log-rank results (sorted by p-value):')
display(results_df)
# Out:
# Log-rank results (sorted by p-value):
#                                      feature    median  logrank_p  n_high  \
# 0                NKT cells (% of leukocytes)  0.016406   0.000046      26
# 1           Ki-67+ T cells (% of CD3+ cells)  0.966289   0.000186      26
# 2            Tbet+ T cells (% of CD3+ cells)  0.179298   0.000211      26
# 3  Tbet+ TCRgd+ T cells (% of TCRgd T cells)  0.792079   0.001149      26
# 4          HLA-DR+ T cells (% of leukocytes)  0.066838   0.186362      26
#
#    n_low
# 0     24
# 1     24
# 2     24
# 3     24
# 4     24

# %%
alpha = 0.05
sig = results_df[results_df['logrank_p'] < alpha].copy()
print(f'Significant features (p < {alpha}):')
display(sig)

for _, row in sig.iterrows():
    feature = row['feature']
    pval = row['logrank_p']
    df = data.loc[~data[feature].isna(), ['OS_time','OS_event', feature]].copy()
    med = df[feature].median()
    high_mask = df[feature] >= med

    plt.figure()
    kmf.fit(
        df.loc[high_mask,'OS_time'],
        event_observed=df.loc[high_mask,'OS_event'],
        label='High (>= median)'
    )
    ax = kmf.plot()

    kmf.fit(
        df.loc[~high_mask,'OS_time'],
        event_observed=df.loc[~high_mask,'OS_event'],
        label='Low (< median)'
    )
    kmf.plot(ax=ax)

    plt.title(
        f"{feature} (baseline {BASELINE_TP}, arm {NIVO_ARM})\n"
        f"log-rank p={pval:.3g}"
    )
    plt.xlabel('Overall survival time')
    plt.ylabel('Survival probability')

    out = 'fig_km_' + ''.join(ch if ch.isalnum() else '_' for ch in feature) + '.png'
    plt.tight_layout()
    plt.savefig(out, dpi=200)
    plt.close()

print('Saved KM plots for significant features.')
# Out:
# Significant features (p < 0.05):
#                                      feature    median  logrank_p  n_high  \
# 0                NKT cells (% of leukocytes)  0.016406   0.000046      26
# 1           Ki-67+ T cells (% of CD3+ cells)  0.966289   0.000186      26
# 2            Tbet+ T cells (% of CD3+ cells)  0.179298   0.000211      26
# 3  Tbet+ TCRgd+ T cells (% of TCRgd T cells)  0.792079   0.001149      26
#
#    n_low
# 0     24
# 1     24
# 2     24
# 3     24
# Saved KM plots for significant features.
