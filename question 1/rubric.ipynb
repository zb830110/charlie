# %% [markdown]
# Total: 100 points

# %% [markdown]
# 2) Loads required input data and performs basic sanity checks.
# - 10: Loads clinical and all available platform datasets, reports dimensions/heads, and correctly restricts to baseline timepoint (e.g., C1D1).sdfsf
# - 5: Loads most inputs but baseline restriction or completeness is unclear.
# - 0: Data loading is largely missing or incorrect.

# %% [markdown]
# 3) Correctly merges biomarkers with clinical survival data.
# - 10: Uses the correct patient-level identifier (Deidentified.ID), avoids double-counting, and reports final sample sizes.
# - 5: Merge is mostly correct but patient-level deduplication or key usage is incomplete.
# - 0: Merge is incorrect (wrong key, duplicated patients, or OS misaligned).

# %% [markdown]
# 4) Defines and applies treatment arms consistently.
# - 10: Correctly defines nivo/chemo and sotiga/chemo arms and filters to evaluable patients per platform, reporting per-arm n.
# - 5: Arm definitions are present but filtering or reporting is incomplete.
# - 0: Arm assignment is incorrect or absent.

# %% [markdown]
# 5) Performs within-arm survival screening.
# - 10: For each arm and platform, performs Cox proportional hazards modeling using a within-arm median high/low split and reports HRs and p-values.
# - 5: Cox models are run but split definition or reporting is incomplete.
# - 0: Survival modeling is missing or incorrect.

# %% [markdown]
# 1) States the analysis goal.
# - 10: Clearly states the goal (baseline circulating biomarkers predictive of OS by regimen), distinguishes arm-specific vs shared, and names all three modalities (flow cytometry/X50, CyTOF, Olink).
# - 5: States the goal but misses modality(ies) or the arm-specific/shared framing.
# - 0: Goal is incorrect or unclear. sdfsf

# %% [markdown]
# 6) Applies multiple-testing correction appropriately.
# - 10: Applies BH-FDR correction within each platform and arm and defines significance using q ≤ 0.10.
# - 5: FDR is applied but inconsistently or with an unclear scope/threshold.
# - 0: No multiple-testing correction.

# %% [markdown]
# 7) Compiles significant biomarkers by arm and platform.
# - 10: Produces a clear compilation of significant biomarkers per arm across flow cytometry, CyTOF, and Olink, explicitly noting platforms with no hits.
# - 5: Compilation is partial or missing a platform.
# - 0: No compilation step.

# %% [markdown]
# 8) Categorizes biomarkers as arm-specific or shared.
# - 10: Clearly defines “shared” (significant in both arms with concordant direction) and applies this classification to all results.
# - 5: Mentions arm-specific vs shared but definition or labeling is incomplete.
# - 0: No arm-specific/shared categorization.

# %% [markdown]
# 9) Evaluates treatment specificity using interaction testing.
# - 10: Performs biomarker × treatment arm interaction testing and reports interaction statistics and FDR results.
# - 5: Interaction testing is attempted but reporting or correction is incomplete.
# - 0: No interaction analysis.

# %% [markdown]
# 10) Provides interpretation and limitations.
# - 10: Interprets arm-specific biomarkers with biologically grounded rationale linked to mechanism (CD40 agonist vs PD-1 blockade) and clearly states key data limitations (sample size, multiple testing, interaction power).
# - 5: Provides either biological rationale or limitations, but not both.
# - 0: No meaningful interpretation or limitations discussion.
